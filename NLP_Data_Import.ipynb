# %% [markdown]
# <a href="https://colab.research.google.com/github/harshtheking100/ML/blob/main/NLP_Data_Import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !pip install PyPDF2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# !pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3957 sha256=b8dd8a69ac86a680813a029a8252d098185544fb436f4efbd86baf2dec776df0
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# **Read Data From docx**

# %%
import docx2txt
import os
dir_path = r'/content/'
os.chdir(dir_path)
result = docx2txt.process("demo.docx")

# %%
result
# Out:
# 'This is a sample text file which I want to parse in python\n\n\n\n\n\nMy file contains abc and xyz\n\n\n\n\n\nI am changing this file for demo'

# %% [markdown]
# **Read Data From PDF**

# %%
import PyPDF2

# %%
dir_path1 = r'/content/Bills'
os.chdir(dir_path1)

# %%
file_list = os.listdir(r'/content/Bills')
for file_name in file_list:
  f = open(file_name, 'rb')
  reader = PyPDF2.PdfReader(f)
  file_contents = reader.pages[0].extract_text().split('\n')

# %%
file_contents
# Out:
# ['Paytm',
#  '1/30/23 4:38 PM',
#  '4:10 PM',
#  ' | 1, Gujrat Colony, Kothrud, Pune, Maharashtra 411038, India',
#  '4:38 PM',
#  ' | 24b, Old Mumbai - Pune Hwy, Sagar Society, Wakadewadi, Bopodi, Pune, Maharashtra 411003, India',
#  'Uber Go ',
#  '    9.94 kilometers | 27',
#  'min',
#  'January 30, 2023',
#  "Here's your receipt for your ride, Harshal",
#  'We hope you enjoyed your ride this morning.',
#  'Total',
#  '₹',
#  '177.93',
#  'Trip Charge',
#  '₹204.50',
#  'Subtotal',
#  '₹',
#  '204.50',
#  'Booking Fee',
#  '₹',
#  '4.83',
#  'Promotion',
#  '-',
#  '₹',
#  '31.40',
#  'Payments',
#  '₹',
#  '177.93',
#  'A temporary hold of ',
#  '₹',
#  '177.84 was placed on your payment method Paytm. This is not a charge and will be removed. It should disappear from',
#  'your bank statement shortly.',
#  'Visit the trip page',
#  ' for more information, including invoices (where available)',
#  'The total of ',
#  '₹',
#  '177.93 has a GST of ',
#  '₹',
#  '10.65 included.',
# ...

# %% [markdown]
# **Beautiful Soup**

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
#Pointing to url
url = 'https://timesofindia.indiatimes.com/home/education/news/career-in-data-science-in-india-courses-certification-salary-future-growth/articleshow/75023624.cms'

# %%
#Sending the request to the url
response = requests.get(url)

# %%
#initializing parser
soup = BeautifulSoup(response.text, "html.parser")

# %%
content = soup.find('div', {"class": "section1"})

# %%
soup.find('div',{"class":"_s30J clearfix"}).text
# Out:
# "There has been an increase in demand for data scientists in India as organisations have been adopting new technologies to analyse the data extensively to draw meaningful insights. Data science has emerged as an attractive career option for freshers as well as experienced professionals. The demand for data engineers is very high in sectors like information technology, telecom, manufacturing, finance and insurance, retail and many more. If you wish to make a career in the high demand career of data science in India, here is all important information that you should have:Data Science courses and certificationsVarious Indian academic institutions offer data analytics/data science courses in the country. The field is data science is often hidden as a specialization in other postgraduate degrees. Here are some of the Indian institutes and universities that offer courses in data science fields:Indian Institute of Information Technology and Management â\x80\x93 KeralaIndian Institute of Sci
# ...

# %%
article = ''
for i in soup.findAll('div'):
  article = article + " " + i.text
article
# Out:
# "    EditionININUSSign InTOIEducationNewsExamsResultsJobsBoardsCareersWeb StoriesEngineeringJEE Main ExamGATE ExamJEE Advanced ExamMedicineNEET UG ExamFuture Skills by EmeritusJEE Main ExamJEE Main Exam DateJEE Main RegistrationJEE Main Application FormJEE Main EligibilityJEE Main SyllabusJEE Main Exam PatternJEE Main Admit CardJEE Main Cut OffJEE Main CounsellingJEE Main Preparation TipsJEE Main Question PaperJEE Main Mock TestJEE Main Dress CodeJEE Main ResultJEE Main Answer KeyJEE Advanced ExamJee Advanced RegistrationJee Advanced EligibilityJee Advanced Exam DateJee Advanced Exam PatternJee Advanced SyllabusJee Advanced Question PaperJee Advanced Mock TestJee Advanced Dress CodeJee Advanced Preparation TipsJee Advanced Admit CardJee Advanced Answer KeyJee Advanced ResultJee Advanced Cut OffJee Advanced CounsellingGATE ExamGATE Application FormGATE Important DatesGATE Admit CardGATE SyllabusGATE Exam PatternGATE Mock TestGATE Preparation TipsGATE Answer KeyGATE ResultGATE Cut OffG
# ...

# %%
with open('output_text.txt', 'w') as file:
    file.write(article)
